# %% [markdown]
# # NLP Project - Machine Translation

# %% [markdown]
# # Preprocessing

# %%
import numpy as np
import re

# Importing our translations
# for example: "spa.txt" or "spa-eng/spa.txt"
data_path = "deu.txt"

# Defining lines as a list of each line
with open(data_path, 'r', encoding='utf-8') as f:
  lines = f.read().split('\n')

# Building empty lists to hold sentences
input_docs = []
target_docs = []
# Building empty vocabulary sets
input_tokens = set()
target_tokens = set()

# Adjust the number of lines so that
# preprocessing doesn't take too long for you
for line in lines[:801]:
  # Input and target sentences are separated by tabs
  input_doc, target_doc = line.split('\t')[:2]
  # Appending each input sentence to input_docs
  input_docs.append(input_doc)

  target_doc = " ".join(re.findall(r"[\w']+|[^\s\w]", target_doc))
  # Redefine target_doc below
  # and append it to target_docs:
  target_doc = '<START> ' + target_doc + ' <END>'
  target_docs.append(target_doc)

  # Now we split up each sentence into words
  # and add each unique word to our vocabulary set
  for token in re.findall(r"[\w']+|[^\s\w]", input_doc):
    # print(token)
    # Add your code here:
    if token not in input_tokens:
      input_tokens.add(token)
  for token in target_doc.split():
    # print(token)
    # And here:
    if token not in target_tokens:
      target_tokens.add(token)

input_tokens = sorted(list(input_tokens))
target_tokens = sorted(list(target_tokens))

# Create num_encoder_tokens and num_decoder_tokens:
num_encoder_tokens = len(input_tokens)
num_decoder_tokens = len(target_tokens)

max_encoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", input_doc)) for input_doc in input_docs])
max_decoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", target_doc)) for target_doc in target_docs])

input_features_dict = dict(
    [(token, i) for i, token in enumerate(input_tokens)])
target_features_dict = dict(
    [(token, i) for i, token in enumerate(target_tokens)])

reverse_input_features_dict = dict(
    (i, token) for token, i in input_features_dict.items())
reverse_target_features_dict = dict(
    (i, token) for token, i in target_features_dict.items())

encoder_input_data = np.zeros(
    (len(input_docs), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

for line, (input_doc, target_doc) in enumerate(zip(input_docs, target_docs)):

  for timestep, token in enumerate(re.findall(r"[\w']+|[^\s\w]", input_doc)):
    # Assign 1. for the current line, timestep, & word
    # in encoder_input_data:
    encoder_input_data[line, timestep, input_features_dict[token]] = 1.

  for timestep, token in enumerate(target_doc.split()):

    decoder_input_data[line, timestep, target_features_dict[token]] = 1.
    
    if timestep > 0:
      decoder_target_data[line, timestep - 1, target_features_dict[token]] = 1.

# print out those value here:
print(list(input_features_dict.keys())[:50])
# Out:
# ['!', '$', ',', '.', '19', '5', '?', 'Aim', 'All', 'Am', 'Answer', 'Ask', 'Attack', 'Awesome', 'Back', 'Be', 'Beat', 'Begin', 'Birds', 'Bless', 'Burn', 'Bury', 'Buy', 'Call', 'Calm', 'Can', 'Catch', 'Cheer', 'Cheers', 'Chill', 'Come', 'Cool', 'Cuff', 'DJ', 'Did', 'Do', 'Dogs', "Don't", 'Drive', 'Drop', 'Duck', 'Eat', 'Excuse', 'Fantastic', 'Feel', 'Find', 'Fire', 'Fix', 'Fold', 'Follow']

# %% [markdown]
# # Training-Model

# %%
import tensorflow as tf

# %%
#from preprocessing import num_encoder_tokens, num_decoder_tokens, decoder_target_data, encoder_input_data, decoder_input_data, decoder_target_data

from tensorflow import keras
# Add Dense to the imported layers
from keras.layers import Input, LSTM, Dense
from keras.models import Model

# %%
# UNCOMMENT THE TWO LINES BELOW IF YOU ARE GETTING ERRORS ON A MAC
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# Choose a dimensionality
latent_dim = 256

# Choose a batch size
# and a larger number of epochs:
batch_size = 50
epochs = 50

# Encoder training setup
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_hidden, state_cell = encoder_lstm(encoder_inputs)
encoder_states = [state_hidden, state_cell]

# Decoder training setup:
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, decoder_state_hidden, decoder_state_cell = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Building the training model:
training_model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

print("Model summary:\n")
training_model.summary()
print("\n\n")

# Compile the model:
training_model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# print("Training the model:\n")
# Train the model:
training_model.fit([encoder_input_data, decoder_input_data], decoder_target_data, batch_size = batch_size, epochs = epochs, validation_split = 0.2)

training_model.save('training_model.h5')
# Out:
# Model summary:
#
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 341)]  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None, 623)]  0
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 256), (None, 612352      input_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, None, 256),  901120      input_2[0][0]
#                                                                  lstm[0][1]
#                                                                  lstm[0][2]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, None, 623)    160111      lstm_1[0][0]
# ==================================================================================================
# Total params: 1,673,583
# Trainable params: 1,673,583
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
#
#
# Epoch 1/50
# 13/13 [==============================] - 7s 149ms/step - loss: 1.8657 - accuracy: 0.0722 - val_loss: 1.6352 - val_accuracy: 0.0769
# Epoch 2/50
# 13/13 [==============================] - 1s 62ms/step - loss: 1.4540 - accuracy: 0.0769 - val_loss: 1.5790 - val_accuracy: 0.0769
# Epoch 3/50
# 13/13 [==============================] - 1s 55ms/step - loss: 1.4005 - accuracy: 0.0912 - val_loss: 1.5493 - val_accuracy: 0.0994
# Epoch 4/50
# 13/13 [==============================] - 1s 48ms/step - loss: 1.3660 - accuracy: 0.0975 - val_loss: 1.5413 - val_accuracy: 0.0994
# Epoch 5/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.3471 - accuracy: 0.0987 - val_loss: 1.5370 - val_accuracy: 0.0994
# Epoch 6/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.3278 - accuracy: 0.1031 - val_loss: 1.5138 - val_accuracy: 0.1070
# Epoch 7/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.3131 - accuracy: 0.1066 - val_loss: 1.5245 - val_accuracy: 0.1018
# Epoch 8/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.2975 - accuracy: 0.1085 - val_loss: 1.4921 - val_accuracy: 0.1099
# Epoch 9/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.2781 - accuracy: 0.1153 - val_loss: 1.5501 - val_accuracy: 0.0994
# Epoch 10/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.2731 - accuracy: 0.1167 - val_loss: 1.5024 - val_accuracy: 0.1132
# Epoch 11/50
# 13/13 [==============================] - 1s 50ms/step - loss: 1.2538 - accuracy: 0.1258 - val_loss: 1.5168 - val_accuracy: 0.1094
# Epoch 12/50
# 13/13 [==============================] - 1s 48ms/step - loss: 1.2440 - accuracy: 0.1261 - val_loss: 1.5219 - val_accuracy: 0.1080
# Epoch 13/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.2297 - accuracy: 0.1329 - val_loss: 1.5081 - val_accuracy: 0.1142
# Epoch 14/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.2269 - accuracy: 0.1303 - val_loss: 1.5326 - val_accuracy: 0.1070
# Epoch 15/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.2049 - accuracy: 0.1386 - val_loss: 1.5610 - val_accuracy: 0.1099
# Epoch 16/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.2042 - accuracy: 0.1392 - val_loss: 1.5322 - val_accuracy: 0.1128
# Epoch 17/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.1886 - accuracy: 0.1458 - val_loss: 1.5608 - val_accuracy: 0.1104
# Epoch 18/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.1780 - accuracy: 0.1518 - val_loss: 1.5545 - val_accuracy: 0.1123
# Epoch 19/50
# 13/13 [==============================] - 1s 48ms/step - loss: 1.1682 - accuracy: 0.1541 - val_loss: 1.5691 - val_accuracy: 0.1128
# Epoch 20/50
# 13/13 [==============================] - 1s 51ms/step - loss: 1.1595 - accuracy: 0.1561 - val_loss: 1.5191 - val_accuracy: 0.1338
# Epoch 21/50
# 13/13 [==============================] - 1s 50ms/step - loss: 1.1500 - accuracy: 0.1578 - val_loss: 1.5317 - val_accuracy: 0.1247
# Epoch 22/50
# 13/13 [==============================] - 1s 56ms/step - loss: 1.1387 - accuracy: 0.1614 - val_loss: 1.5748 - val_accuracy: 0.1147
# Epoch 23/50
# 13/13 [==============================] - 1s 54ms/step - loss: 1.1334 - accuracy: 0.1626 - val_loss: 1.5442 - val_accuracy: 0.1242
# Epoch 24/50
# 13/13 [==============================] - 1s 58ms/step - loss: 1.1223 - accuracy: 0.1624 - val_loss: 1.5744 - val_accuracy: 0.1161
# Epoch 25/50
# 13/13 [==============================] - 1s 70ms/step - loss: 1.1139 - accuracy: 0.1661 - val_loss: 1.5690 - val_accuracy: 0.1204
# Epoch 26/50
# 13/13 [==============================] - 1s 60ms/step - loss: 1.1088 - accuracy: 0.1642 - val_loss: 1.5377 - val_accuracy: 0.1276
# Epoch 27/50
# 13/13 [==============================] - 1s 63ms/step - loss: 1.0968 - accuracy: 0.1659 - val_loss: 1.5526 - val_accuracy: 0.1276
# Epoch 28/50
# 13/13 [==============================] - 1s 50ms/step - loss: 1.0872 - accuracy: 0.1689 - val_loss: 1.5888 - val_accuracy: 0.1199
# Epoch 29/50
# 13/13 [==============================] - 1s 46ms/step - loss: 1.0803 - accuracy: 0.1668 - val_loss: 1.5872 - val_accuracy: 0.1228
# Epoch 30/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.0741 - accuracy: 0.1701 - val_loss: 1.5548 - val_accuracy: 0.1328
# Epoch 31/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.0615 - accuracy: 0.1715 - val_loss: 1.5794 - val_accuracy: 0.1271
# Epoch 32/50
# 13/13 [==============================] - 1s 46ms/step - loss: 1.0593 - accuracy: 0.1721 - val_loss: 1.5657 - val_accuracy: 0.1309
# Epoch 33/50
# 13/13 [==============================] - 1s 46ms/step - loss: 1.0506 - accuracy: 0.1750 - val_loss: 1.5566 - val_accuracy: 0.1390
# Epoch 34/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.0369 - accuracy: 0.1756 - val_loss: 1.6138 - val_accuracy: 0.1185
# Epoch 35/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.0342 - accuracy: 0.1766 - val_loss: 1.5649 - val_accuracy: 0.1371
# Epoch 36/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.0237 - accuracy: 0.1788 - val_loss: 1.5645 - val_accuracy: 0.1438
# Epoch 37/50
# 13/13 [==============================] - 1s 47ms/step - loss: 1.0167 - accuracy: 0.1780 - val_loss: 1.5617 - val_accuracy: 0.1381
# Epoch 38/50
# 13/13 [==============================] - 1s 52ms/step - loss: 1.0088 - accuracy: 0.1802 - val_loss: 1.5860 - val_accuracy: 0.1300
# Epoch 39/50
# 13/13 [==============================] - 1s 53ms/step - loss: 0.9993 - accuracy: 0.1810 - val_loss: 1.5743 - val_accuracy: 0.1395
# Epoch 40/50
# 13/13 [==============================] - 1s 54ms/step - loss: 0.9926 - accuracy: 0.1811 - val_loss: 1.5514 - val_accuracy: 0.1476
# Epoch 41/50
# 13/13 [==============================] - 1s 53ms/step - loss: 0.9839 - accuracy: 0.1810 - val_loss: 1.5731 - val_accuracy: 0.1429
# Epoch 42/50
# 13/13 [==============================] - 1s 47ms/step - loss: 0.9761 - accuracy: 0.1820 - val_loss: 1.5827 - val_accuracy: 0.1467
# Epoch 43/50
# 13/13 [==============================] - 1s 48ms/step - loss: 0.9685 - accuracy: 0.1843 - val_loss: 1.5948 - val_accuracy: 0.1400
# Epoch 44/50
# 13/13 [==============================] - 1s 47ms/step - loss: 0.9613 - accuracy: 0.1849 - val_loss: 1.5594 - val_accuracy: 0.1505
# Epoch 45/50
# 13/13 [==============================] - 1s 47ms/step - loss: 0.9557 - accuracy: 0.1843 - val_loss: 1.5756 - val_accuracy: 0.1495
# Epoch 46/50
# 13/13 [==============================] - 1s 54ms/step - loss: 0.9438 - accuracy: 0.1869 - val_loss: 1.6063 - val_accuracy: 0.1409
# Epoch 47/50
# 13/13 [==============================] - 1s 53ms/step - loss: 0.9393 - accuracy: 0.1882 - val_loss: 1.5888 - val_accuracy: 0.1414
# Epoch 48/50
# 13/13 [==============================] - 1s 53ms/step - loss: 0.9313 - accuracy: 0.1887 - val_loss: 1.6042 - val_accuracy: 0.1381
# Epoch 49/50
# 13/13 [==============================] - 1s 58ms/step - loss: 0.9262 - accuracy: 0.1882 - val_loss: 1.5818 - val_accuracy: 0.1510
# Epoch 50/50
# 13/13 [==============================] - 1s 52ms/step - loss: 0.9168 - accuracy: 0.1918 - val_loss: 1.5867 - val_accuracy: 0.1481

# %%
#Test-function

# %%
#from preprocessing import input_features_dict, target_features_dict, reverse_input_features_dict, reverse_target_features_dict, max_decoder_seq_length, input_docs, target_docs, input_tokens, target_tokens
#from training_model import encoder_inputs, decoder_inputs, encoder_states, decoder_lstm, decoder_dense, encoder_input_data, num_decoder_tokens, latent_dim

from tensorflow import keras
from keras.layers import Input, LSTM, Dense
from keras.models import Model, load_model
import numpy as np

training_model = load_model('training_model.h5')
encoder_inputs = training_model.input[0]
encoder_outputs, state_h_enc, state_c_enc = training_model.layers[2].output
encoder_states = [state_h_enc, state_c_enc]

encoder_model = Model(encoder_inputs, encoder_states)


decoder_state_input_hidden = Input(shape=(latent_dim,))
decoder_state_input_cell = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_hidden, decoder_state_input_cell]
decoder_outputs, state_hidden, state_cell = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_hidden, state_cell]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

def decode_sequence(test_input):
  # Encode the input as state vectors.
  states_value = encoder_model.predict(test_input)

  # Generate empty target sequence of length 1.
  target_seq = np.zeros((1, 1, num_decoder_tokens))
  # Populate the first token of target sequence with the start token.
  target_seq[0, 0, target_features_dict['<START>']] = 1.

  # Sampling loop for a batch of sequences
  # (to simplify, here we assume a batch of size 1).
  decoded_sentence = ''

  stop_condition = False
  while not stop_condition:
    # Run the decoder model to get possible 
    # output tokens (with probabilities) & states
    output_tokens, hidden_state, cell_state = decoder_model.predict(
      [target_seq] + states_value)

    # Choose token with highest probability
    sampled_token_index = np.argmax(output_tokens[0, -1, :])
    sampled_token = reverse_target_features_dict[sampled_token_index]
    decoded_sentence += " " + sampled_token

    # Exit condition: either hit max length
    # or find stop token.
    if (sampled_token == '<END>' or len(decoded_sentence) > max_decoder_seq_length):
      stop_condition = True

    # Update the target sequence (of length 1).
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0, 0, sampled_token_index] = 1.

    # Update states
    states_value = [hidden_state, cell_state]

  return decoded_sentence


# CHANGE RANGE (NUMBER OF TEST SENTENCES TO TRANSLATE) AS YOU PLEASE
for seq_index in range(100):
  test_input = encoder_input_data[seq_index: seq_index + 1]
  decoded_sentence = decode_sequence(test_input)
  print('-')
  print('Input sentence:', input_docs[seq_index])
  print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence:  Geh dich . <END>
# -
# Input sentence: Hi.
# Decoded sentence:  Tom ! ! <END>
# -
# Input sentence: Hi.
# Decoded sentence:  Tom ! ! <END>
# -
# Input sentence: Run!
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Run.
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Wow!
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Wow!
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Duck!
# Decoded sentence:  Wie ! ! <END>
# -
# Input sentence: Fire!
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Help!
# Decoded sentence:  Wie ! ! <END>
# -
# Input sentence: Help!
# Decoded sentence:  Wie ! ! <END>
# -
# Input sentence: Stay.
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Stop!
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Stop!
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Wait!
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Wait.
# Decoded sentence:  Sie . . <END>
# -
# Input sentence: Begin.
# Decoded sentence:  Tom Sie . <END>
# -
# Input sentence: Do it.
# Decoded sentence:  Sie es . <END>
# -
# Input sentence: Do it.
# Decoded sentence:  Sie es . <END>
# -
# Input sentence: Go on.
# Decoded sentence:  Geh dich . <END>
# -
# Input sentence: Hello!
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Hello!
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Hurry!
# Decoded sentence:  Mach ! ! <END>
# -
# Input sentence: Hurry!
# Decoded sentence:  Mach ! ! <END>
# -
# Input sentence: I hid.
# Decoded sentence:  Ich bin . . <END>
# -
# Input sentence: I hid.
# Decoded sentence:  Ich bin . . <END>
# -
# Input sentence: I ran.
# Decoded sentence:  Ich habe . <END>
# -
# Input sentence: I see.
# Decoded sentence:  Ich . <END>
# -
# Input sentence: I see.
# Decoded sentence:  Ich . <END>
# -
# Input sentence: I try.
# Decoded sentence:  Ich bin . . <END>
# -
# Input sentence: I try.
# Decoded sentence:  Ich bin . . <END>
# -
# Input sentence: I won!
# Decoded sentence:  Ich habe . . <END>
# -
# Input sentence: I won!
# Decoded sentence:  Ich habe . . <END>
# -
# Input sentence: I won.
# Decoded sentence:  Ich bin . . <END>
# -
# Input sentence: Oh no!
# Decoded sentence:  Kopf für ! ! <END>
# -
# Input sentence: Relax.
# Decoded sentence:  Mach dich . <END>
# -
# Input sentence: Shoot!
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Shoot!
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Smile.
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Sorry?
# Decoded sentence:  Wirklich ? <END>
# -
# Input sentence: Ask me.
# Decoded sentence:  Frag mich ! <END>
# -
# Input sentence: Ask me.
# Decoded sentence:  Frag mich ! <END>
# -
# Input sentence: Ask me.
# Decoded sentence:  Frag mich ! <END>
# -
# Input sentence: Attack!
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Attack!
# Decoded sentence:  ! ! <END>
# -
# Input sentence: Buy it.
# Decoded sentence:  Fallen Sie ! !
# -
# Input sentence: Cheers!
# Decoded sentence:  Wie ! ! <END>
# -
# Input sentence: Eat it.
# Decoded sentence:  Sie es . <END>
# -
# Input sentence: Eat up.
# Decoded sentence:  Mach Sie ! <END>
# -
# Input sentence: Eat up.
# Decoded sentence:  Mach Sie ! <END>
# -
# Input sentence: Eat up.
# Decoded sentence:  Mach Sie ! <END>
# -
# Input sentence: Freeze!
# Decoded sentence:  Sers ! <END>
# -
# Input sentence: Freeze!
# Decoded sentence:  Sers ! <END>
# -
# Input sentence: Go now.
# Decoded sentence:  Geh dich . <END>
# -
# Input sentence: Got it!
# Decoded sentence:  Ich ! <END>
# -
# Input sentence: Got it!
# Decoded sentence:  Ich ! <END>
# -
# Input sentence: Got it!
# Decoded sentence:  Ich ! <END>
# -
# Input sentence: Got it?
# Decoded sentence:  Wer ? <END>
# -
# Input sentence: Got it?
# Decoded sentence:  Wer ? <END>
# -
# Input sentence: Got it?
# Decoded sentence:  Wer ? <END>
# -
# Input sentence: He ran.
# Decoded sentence:  Er ist . <END>
# -
# Input sentence: He ran.
# Decoded sentence:  Er ist . <END>
# -
# Input sentence: Hop in.
# Decoded sentence:  Mach dich ! <END>
# -
# Input sentence: Hop in.
# Decoded sentence:  Mach dich ! <END>
# -
# Input sentence: Hug me.
# Decoded sentence:  Frag mich ! <END>
# -
# Input sentence: Hug me.
# Decoded sentence:  Frag mich ! <END>
# -
# Input sentence: Hug me.
# Decoded sentence:  Frag mich ! <END>
# -
# Input sentence: I care.
# Decoded sentence:  Ich bin . . <END>
# -
# Input sentence: I fell.
# Decoded sentence:  Ich bin . <END>
# -
# Input sentence: I fell.
# Decoded sentence:  Ich bin . <END>
# -
# Input sentence: I fell.
# Decoded sentence:  Ich bin . <END>
# -
# Input sentence: I fell.
# Decoded sentence:  Ich bin . <END>
# -
# Input sentence: I fell.
# Decoded sentence:  Ich bin . <END>
# -
# Input sentence: I fled.
# Decoded sentence:  Ich habe . . <END>
# -
# Input sentence: I fled.
# Decoded sentence:  Ich habe . . <END>
# -
# Input sentence: I know.
# Decoded sentence:  Ich habe . <END>
# -
# Input sentence: I lied.
# Decoded sentence:  Ich habe . <END>
# -
# Input sentence: I lost.
# Decoded sentence:  Ich habe . . <END>
# -
# Input sentence: I paid.
# Decoded sentence:  Ich habe . <END>
# -
# Input sentence: I paid.
# Decoded sentence:  Ich habe . <END>
# -
# Input sentence: I sang.
# Decoded sentence:  Ich habe . <END>
# -
# Input sentence: I spit.
# Decoded sentence:  Ich habe . <END>
# -
# Input sentence: I spit.
# Decoded sentence:  Ich habe . <END>
# -
# Input sentence: I swim.
# Decoded sentence:  Ich habe . <END>
# -
# Input sentence: I wept.
# Decoded sentence:  Ich habe . <END>
# -
# Input sentence: I wept.
# Decoded sentence:  Ich habe . <END>
# -
# Input sentence: I'm 19.
# Decoded sentence:  Ich bin . . <END>
# -
# Input sentence: I'm 19.
# Decoded sentence:  Ich bin . . <END>
# -
# Input sentence: I'm OK.
# Decoded sentence:  Ich bin . . <END>
# -
# Input sentence: I'm OK.
# Decoded sentence:  Ich bin . . <END>
# -
# Input sentence: I'm up.
# Decoded sentence:  Ich bin . . <END>
# -
# Input sentence: I'm up.
# Decoded sentence:  Ich bin . . <END>
# -
# Input sentence: Listen.
# Decoded sentence:  Sie es . <END>
# -
# Input sentence: No way!
# Decoded sentence:  Komm ! <END>
# -
# Input sentence: No way!
# Decoded sentence:  Komm ! <END>
# -
# Input sentence: No way!
# Decoded sentence:  Komm ! <END>
# -
# Input sentence: No way!
# Decoded sentence:  Komm ! <END>
# -
# Input sentence: No way!
# Decoded sentence:  Komm ! <END>
# -
# Input sentence: Really?
# Decoded sentence:  Wer ? <END>
# -
# Input sentence: Really?
# Decoded sentence:  Wer ? <END>
